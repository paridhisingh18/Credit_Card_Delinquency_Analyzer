# %%
#Importing libraries
import pandas as pd
import numpy as np

# %%
## Load CSV 
df=pd.read_csv('UCI_Credit_Card.csv')
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
df.rename(columns={
    'PAY_0': 'PAY_1',
    'default.payment.next.month': 'DEFAULT'
}, inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'DEFAULT'],
#       dtype='object')

# %%
df.drop(columns='ID' , inplace= True)

# %%
#Checking for null values and duplicate rows
print("Null Values:", df.isnull().sum())
print("Duplicate Row:" , df.duplicated().sum())
# Out:
# Null Values: LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_1        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# DEFAULT      0
# dtype: int64
# Duplicate Row: 35

# %%
#drop the duplicate rows
df= df.drop_duplicates()
print("Dublicate rows are Deleted")
# Out:
# Dublicate rows are Deleted

# %%
df.shape
# Out:
# (29965, 24)

# %%
df.loc[:, 'SEX'] = df['SEX'].replace({
    1: 'Male',
    2: 'Female'
}).astype('category')

# %%
df.loc[:, 'EDUCATION'] = df['EDUCATION'].replace({
    1: 'Graduate School',
    2: 'University',
    3: 'High School',
    4: 'Others',
    5: 'Unknown',
    6: 'Unknown',
    0: 'Unknown'
}).astype('category')

df.loc[:, 'MARRIAGE'] = df['MARRIAGE'].replace({
    1: 'Married',
    2: 'Single',
    3: 'Others',
    0: 'Unknown'
}).astype('category')

# %%
df.head(10)
# Out:
#    LIMIT_BAL     SEX        EDUCATION MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0    20000.0  Female       University  Married   24      2      2     -1
# 1   120000.0  Female       University   Single   26     -1      2      0
# 2    90000.0  Female       University   Single   34      0      0      0
# 3    50000.0  Female       University  Married   37      0      0      0
# 4    50000.0    Male       University  Married   57     -1      0     -1
# 5    50000.0    Male  Graduate School   Single   37      0      0      0
# 6   500000.0    Male  Graduate School   Single   29      0      0      0
# 7   100000.0  Female       University   Single   23      0     -1     -1
# 8   140000.0  Female      High School  Married   28      0      0      2
# 9    20000.0    Male      High School   Single   35     -2     -2     -2
#
#    PAY_4  PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -2  ...        0.0        0.0        0.0       0.0     689.0
# ...

# %%
# 1. Total bill amount
df.loc[:, 'TOTAL_BILL'] = df[[f'BILL_AMT{i}' for i in range(1, 7)]].sum(axis=1)

# 2. Total paid amount
df.loc[:, 'TOTAL_PAID'] = df[[f'PAY_AMT{i}' for i in range(1, 7)]].sum(axis=1)

# 3. Payment ratio
df.loc[:, 'PAY_RATIO'] = df['TOTAL_PAID'] / df['TOTAL_BILL'].replace(0, 1)

# 4. Average delay
pay_cols = [f'PAY_{i}' for i in range(1, 7)]
df.loc[:, 'AVG_DELAY'] = df[pay_cols].replace({-2: 0, -1: 0}).mean(axis=1)

# %%
df.info()
df.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29965 entries, 0 to 29999
# Data columns (total 28 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LIMIT_BAL   29965 non-null  float64
#  1   SEX         29965 non-null  category
#  2   EDUCATION   29965 non-null  object
#  3   MARRIAGE    29965 non-null  object
#  4   AGE         29965 non-null  int64
#  5   PAY_1       29965 non-null  int64
#  6   PAY_2       29965 non-null  int64
#  7   PAY_3       29965 non-null  int64
#  8   PAY_4       29965 non-null  int64
#  9   PAY_5       29965 non-null  int64
#  10  PAY_6       29965 non-null  int64
#  11  BILL_AMT1   29965 non-null  float64
#  12  BILL_AMT2   29965 non-null  float64
#  13  BILL_AMT3   29965 non-null  float64
#  14  BILL_AMT4   29965 non-null  float64
#  15  BILL_AMT5   29965 non-null  float64
#  16  BILL_AMT6   29965 non-null  float64
#  17  PAY_AMT1    29965 non-null  float64
#  18  PAY_AMT2    29965 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL     0
# SEX           0
# EDUCATION     0
# MARRIAGE      0
# AGE           0
# PAY_1         0
# PAY_2         0
# PAY_3         0
# PAY_4         0
# PAY_5         0
# PAY_6         0
# BILL_AMT1     0
# BILL_AMT2     0
# BILL_AMT3     0
# BILL_AMT4     0
# BILL_AMT5     0
# BILL_AMT6     0
# PAY_AMT1      0
# PAY_AMT2      0
# PAY_AMT3      0
# PAY_AMT4      0
# PAY_AMT5      0
# PAY_AMT6      0
# DEFAULT       0
# TOTAL_BILL    0
# TOTAL_PAID    0
# PAY_RATIO     0
# AVG_DELAY     0
# dtype: int64

# %%
# Saving the cleaned file to the cleaned_data folder
df.to_csv('credit_card_default_cleaned.csv', index=False)

print("✅ Cleaned file saved successfully!")
# Out:
# ✅ Cleaned file saved successfully!
